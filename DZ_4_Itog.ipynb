# %% [markdown]
# <a href="https://colab.research.google.com/github/MazurovaNN/Python_analit/blob/main/DZ_4_Itog.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##Условие 1:
# ##Задача 1
# Постройте график Назовите график Сделайте именование оси x и оси y Сделайте выводы
#
# 1.1. Скачать данные по ссылке https://www.kaggle.com/datasets/ionaskel/laptop-prices

# %%
df = pd.read_csv('kc_house_data.csv', sep=",", encoding='windows-1251')
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df['price'].min()
# Out:
# 75000.0

# %% [markdown]
# ##1.2 Изучите стоимости недвижимости

# %%
plt.figure(figsize=(16, 8))
sns.histplot(df['price'])
plt.ticklabel_format(style='plain')
plt.title('Распределение стоимости недвижимости')
plt.xlabel('Стоимость')
plt.ylabel('Количество');

# %% [markdown]
# ##1.3 Изучите распределение квадратуры жилой

# %%
plt.figure(figsize=(16, 6))
sns.histplot(df['sqft_living'])
plt.ticklabel_format(style='plain')
plt.title('Распределение жилой площади')
plt.xlabel('Площадь')
plt.ylabel('Количество');

# %% [markdown]
# ##1.4 Изучите распределение года постройки

# %%
plt.figure(figsize=(12, 6))
sns.histplot(df['yr_built'])
plt.ticklabel_format(style='plain')
plt.title('Распределение года постройки')
plt.xlabel('Год постройки')
plt.ylabel('Количество');

# %% [markdown]
# #Условие 2:
# ##2 задача
# ##2.1 Изучите распределение домов от наличия вида на набережную
# Постройте график

# %%
data_1 = df['waterfront'].value_counts()
data_1
# Out:
# 0    21450
# 1      163
# Name: waterfront, dtype: int64

# %%
labels = ['Есть вид', 'Нет вида']
plt.pie(data_1, autopct='%1.1f%%', labels=labels)
plt.title('Распределение домов от наличия вида на набережную');

# %% [markdown]
# ##2.2 Изучите распределение этажей домов

# %%
data_2 = df['floors'].value_counts()
data_2
# Out:
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: floors, dtype: int64

# %%
plt.figure(figsize=(6, 4))
sns.barplot(x = data_2.index, y = data_2)
plt.title('Распределение этажей домов')
plt.xlabel('Количество этажей')
plt.ylabel('Количество')
plt.xticks(rotation=35);

# %% [markdown]
# ##2.2 Изучите распределение состояния домов

# %%
data_3 = df['condition'].value_counts()
data_3
# Out:
# 3    14031
# 4     5679
# 5     1701
# 2      172
# 1       30
# Name: condition, dtype: int64

# %%
plt.figure(figsize=(6, 4))
sns.barplot(x = data_3.index, y = data_3)
plt.title('Распределение состояния домов')
plt.xlabel('Состояние дома')
plt.ylabel('Количество');

# %% [markdown]
# ##Условие 3:
# ##3 задача
# Исследуйте, какие характеристики недвижимости влияют на стоимость недвижимости, с применением не менее 5 диаграмм из урока. Анализ сделайте в формате storytelling: дополнить каждый график письменными выводами и наблюдениями.

# %%
sns.jointplot(x=df['price'], y=df['sqft_living'], kind='reg') 
sns.jointplot(x=df['price'], y=df['sqft_above'], kind='reg')
sns.jointplot(x=df['price'], y=df['grade'], kind='reg')
sns.jointplot(x=df['price'], y=df['bedrooms'], kind='reg')
sns.jointplot(x=df['price'], y=df['bathrooms'], kind='reg')
sns.jointplot(x=df['price'], y=df['yr_built'], kind='reg');

# %% [markdown]
# Изучив данные диаграммы, я делаю вывод, что на стоимость недвижимости в  большей степени влияют:
# ##-жилая площадь
# ##-общая площадь
# ## -высокое качество конструкции и дизайна
# ##-количество ванных комнат
#
# Меньше влияет на стоимость невидимости:
#
# ## -год постройки
# ##-количество спален
